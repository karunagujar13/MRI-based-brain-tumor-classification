# %%
# import Opencv 
import cv2 
  
# import Numpy 
import numpy as np 
  
# read a image using imread 
import matplotlib.pyplot as plt

# %%
IM_PATH = './data/Training/glioma_tumor/gg (4).jpg'

# %%
img = cv2.imread(IM_PATH)

gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# creating a Histograms Equalization 
# of a image using cv2.equalizeHist() 
equ = cv2.equalizeHist(gray) 
  
# stacking images side-by-side 
res = np.hstack((gray, equ)) 
  
# show image input vs output 
#cv2.imshow('image', res) 
imgplot = plt.imshow(res)

cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np


def hist_normalization(img)

    img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

    # equalize the histogram of the Y channel
    img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

    # convert the YUV image back to RGB format
    img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

    cv2.waitKey(0)
    return img_output
# Out:
# -1

# %%
from scipy import ndimage, misc
import numpy as np
import os
import cv2

OUT_PATH = "./data/processed_data/Training/"
PATH = "./data/Training/"

    # iterate through the names of contents of the folder
    folders = os.listdir(PATH)
    for f in folders:
        print('****** Processing folder: 'f)
        in_path = PATH + '/' + f
        final_out_path = OUT_PATH + '/' +f
    for image_path in os.listdir(in_path):
        print('Processing imgae: 'image_path)
        # create the full input path and read the file
        input_path = os.path.join(path, image_path)
        image_to_process = ndimage.imread(input_path)

        # rotate the image
        processed = hist_normalization(image_to_process)

        # create full output path, 'example.jpg' 
        # becomes 'rotate_example.jpg', save the file to disk
        fullpath = os.path.join(OUT_PATH, image_path)
        print('-------Saving processed image to: ',fullpath)
        misc.imsave(fullpath, processed)
